# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
from IPython.display import display
import os
parent_dir = os.path.abspath(os.path.join(os.getcwd(), os.pardir))
print(f"Parent directory: {parent_dir}")
# Out:
# Parent directory: /u/weim/lob

# %%
# Should update this to include: Dirichlet, Normal+Softmax 
# Note: need more training iterations like 400 (or 500 iterations)
# For 200 iterations, in the noise setting, the rl agent is not better than the noise agent 
# note dirichlet agents also seeems to work well 
lots_list = [40,120]
n_samples = 10000
train_iter = 400
tag = 'GAE'  # could be empty string ''
tag = 'long_horizon'
# tag = 'deterministic_action'
batch_size= 12800


folder_path = f"{parent_dir}/rewards"
data = {}
# agent_list = ['sl_agent', 'linear_sl_agent',  'dirichlet', 'log_normal']
agent_list = ['sl_agent', 'linear_sl_agent',  'log_normal']
for env in ['noise', 'flow', 'strategic']:
    data[env] = {}
    for lots in lots_list:
        data[env][lots] = {}
        for agent in agent_list:            
            try: 
                # rl strategies 
                if agent in ['log_normal', 'log_normal_learn_std', 'dirichlet']:               
                    # long_horizon twice. typo in code. 
                    name =  f'{folder_path}/{env}_{lots}_seed_0_eval_seed_100_eval_episodes_10000_num_iterations_{train_iter}_bsize_{batch_size}_{agent}_long_horizon_long_horizon.npz'
                else:
                    # might need to updating the naming here
                    name = f'{folder_path}/{env}_{lots}_episodes_{10000}_eval_seed_100_{agent}_long_horizon.npz'
                    # name = f'{folder_path}/{env}_{lots}_episodes_{10000}_eval_seed_100_{agent}.npz'
                print(f'loading from {name}')
                data[env][lots][agent] = np.load(name)['rewards']
            except:
                print(f"path doesnt exist: {name}")
                data[env][lots][agent] = 'no data aviailable'
# Out:
# loading from /u/weim/lob/rewards/noise_40_episodes_10000_eval_seed_100_sl_agent_long_horizon.npz
# loading from /u/weim/lob/rewards/noise_40_episodes_10000_eval_seed_100_linear_sl_agent_long_horizon.npz
# loading from /u/weim/lob/rewards/noise_40_seed_0_eval_seed_100_eval_episodes_10000_num_iterations_400_bsize_12800_log_normal_long_horizon_long_horizon.npz
# loading from /u/weim/lob/rewards/noise_120_episodes_10000_eval_seed_100_sl_agent_long_horizon.npz
# loading from /u/weim/lob/rewards/noise_120_episodes_10000_eval_seed_100_linear_sl_agent_long_horizon.npz
# loading from /u/weim/lob/rewards/noise_120_seed_0_eval_seed_100_eval_episodes_10000_num_iterations_400_bsize_12800_log_normal_long_horizon_long_horizon.npz
# loading from /u/weim/lob/rewards/flow_40_episodes_10000_eval_seed_100_sl_agent_long_horizon.npz
# loading from /u/weim/lob/rewards/flow_40_episodes_10000_eval_seed_100_linear_sl_agent_long_horizon.npz
# loading from /u/weim/lob/rewards/flow_40_seed_0_eval_seed_100_eval_episodes_10000_num_iterations_400_bsize_12800_log_normal_long_horizon_long_horizon.npz
# loading from /u/weim/lob/rewards/flow_120_episodes_10000_eval_seed_100_sl_agent_long_horizon.npz
# loading from /u/weim/lob/rewards/flow_120_episodes_10000_eval_seed_100_linear_sl_agent_long_horizon.npz
# loading from /u/weim/lob/rewards/flow_120_seed_0_eval_seed_100_eval_episodes_10000_num_iterations_400_bsize_12800_log_normal_long_horizon_long_horizon.npz
# loading from /u/weim/lob/rewards/strategic_40_episodes_10000_eval_seed_100_sl_agent_long_horizon.npz
# loading from /u/weim/lob/rewards/strategic_40_episodes_10000_eval_seed_100_linear_sl_agent_long_horizon.npz
# loading from /u/weim/lob/rewards/strategic_40_seed_0_eval_seed_100_eval_episodes_10000_num_iterations_400_bsize_12800_log_normal_long_horizon_long_horizon.npz
# loading from /u/weim/lob/rewards/strategic_120_episodes_10000_eval_seed_100_sl_agent_long_horizon.npz
# loading from /u/weim/lob/rewards/strategic_120_episodes_10000_eval_seed_100_linear_sl_agent_long_horizon.npz
# loading from /u/weim/lob/rewards/strategic_120_seed_0_eval_seed_100_eval_episodes_10000_num_iterations_400_bsize_12800_log_normal_long_horizon_long_horizon.npz

# %%
folder_path = f"{parent_dir}/latex_tables"
list_of_dfs = []
# n_lots = [20, 60]
# print(filler)
for env in ['noise', 'flow', 'strategic']:
    data_for_df = {}
    name_dict = {'sl_agent': 'SL', 'linear_sl_agent': 'TWAP', 'dirichlet': 'DR', 'log_normal': 'LN'}
    # agent_names = ['sl_agent', 'linear_sl_agent', 'dirichlet', 'log_normal']
    agent_names = ['sl_agent', 'linear_sl_agent', 'dirichlet', 'log_normal']
    for agent in agent_names:
        print(agent)
        name = name_dict[agent]
        data_for_df[f'E[{name}]'] = []
        data_for_df[f'Std[{name}]'] = []
        for lots in lots_list:
            try:
                data_for_df[f'Std[{name}]'] += [np.std(data[env][lots][agent])]
                data_for_df[f'E[{name}]'] += [np.mean(data[env][lots][agent])]                
            except:
                print(f"no data available for {env}, {lots}, {agent}")
                data_for_df[f'Std[{name}]'] += [np.nan]
                data_for_df[f'E[{name}]'] += [np.nan]
    df = pd.DataFrame.from_dict(data_for_df).round(2)    
    df.index.name = 'Lots'
    index_name = [f'{env}_{l}' for l in lots_list]
    df.index = index_name
    df = df.round(2)
    list_of_dfs.append(df)

complete_df = pd.concat(list_of_dfs, axis=0)
print(complete_df)


highest_exp = []
lowest_std = []
for idx in complete_df.index:
    expected_values = complete_df.loc[idx, ['E[SL]', 'E[TWAP]', 'E[DR]', 'E[LN]']]
    max_idx = expected_values.idxmax()
    highest_exp.append((idx, max_idx))
    std_values = complete_df.loc[idx, ['Std[SL]', 'Std[TWAP]', 'Std[DR]', 'Std[LN]']]
    min_idx = std_values.idxmin()
    lowest_std.append((idx, min_idx))

complete_df = complete_df.astype(str)
for idx, max_idx in highest_exp:
    complete_df.loc[idx, max_idx] = fr"\textbf{{{complete_df.loc[idx, max_idx]}}}"

# dont highlight std for now
# for idx, min_idx in lowest_std:
#     complete_df.loc[idx, min_idx] = fr"\textbf{{{complete_df.loc[idx, min_idx]}}}"

complete_df = complete_df.drop(['noise', 'flow', 'strategic'], errors='ignore')
complete_df.insert(0, r'\#Lots', complete_df.index.astype(str))
#
complete_df.iloc[:,0] = [40,120]*3

complete_df.insert(0, r'Market', complete_df.index.astype(str))
complete_df.iloc[:,0] = ['Noise', '', 'Noise \& Tactical', '', 'Noise \& Tactical', '\& Strategic']

rename_dict = {'E[SL]': r'$\mathbb{E}[\text{SL}]$', 'Std[SL]': r'$\sigma[\text{SL}]$', 
               'E[TWAP]': r'$\mathbb{E}[\text{TWAP}]$', 'Std[TWAP]': r'$\sigma[\text{TWAP}]$', 
               'E[LN]': r'$\mathbb{E}[\text{LN}]$', 'Std[LN]': r'$\sigma[\text{LN}]$', 
               'E[DR]': r'$\mathbb{E}[\text{DR}]$', 'Std[DR]': r'$\sigma[\text{DR}]$',
            #    'E[LNVAR]': r'$\mathbb{E}[\text{LNVAR}]$', 'Std[LNVAR]': r'$\sigma[\text{LNVAR}]$'
               }
print(complete_df)
complete_df = complete_df.rename(columns=rename_dict)
complete_df = complete_df.where(pd.notnull(complete_df), '')

latex_table = complete_df.to_latex(float_format="%.2f", index=False, column_format='l'+'c'*9, escape=False)
saving_path = f"{folder_path}/results_table_latest_with_dirichlet_{tag}.tex" if tag is not None else f"{folder_path}/results_table_latest_with_dirichlet.tex"
tag = 'long_horizon' 
saving_path = f"{folder_path}/results_table_log_normal_{tag}.tex" 
tag = '' if tag is None else tag
with open(saving_path, "w") as f:
    content = (
        r"\begin{table}[htpb]"+
        r"\label{table:" + tag +"}"+
        r"\begin{center}"+
        r"    \begin{scriptsize}"+
        r"        \begin{sc}"
        + latex_table +
        r"        \end{sc}"+
        r"    \end{scriptsize}"+
        r"\end{center}"+
        r"\end{table}"        
    )
    f.write(content)
# Out:
# sl_agent
# linear_sl_agent
# dirichlet
# no data available for noise, 40, dirichlet
# no data available for noise, 120, dirichlet
# log_normal
# sl_agent
# linear_sl_agent
# dirichlet
# no data available for flow, 40, dirichlet
# no data available for flow, 120, dirichlet
# log_normal
# sl_agent
# linear_sl_agent
# dirichlet
# no data available for strategic, 40, dirichlet
# no data available for strategic, 120, dirichlet
# log_normal
#                E[SL]  Std[SL]  E[TWAP]  Std[TWAP]  E[DR]  Std[DR]  E[LN]  \
# noise_40       -0.35     1.43    -0.58       1.10    NaN      NaN   0.30
# noise_120      -2.75     1.29    -3.02       1.06    NaN      NaN  -1.64
# flow_40        -2.00     1.43    -0.19       1.00    NaN      NaN   0.61
# flow_120       -5.57     0.77    -4.13       1.03    NaN      NaN  -0.72
# strategic_40   -2.11     3.29    -1.09       3.28    NaN      NaN   2.32
# strategic_120  -3.96     4.01    -3.42       4.18    NaN      NaN   0.26
#
#                Std[LN]
# noise_40          1.40
# noise_120         1.21
# flow_40           0.75
# flow_120          0.81
# strategic_40      3.69
# strategic_120     3.21
#                           Market \#Lots  E[SL] Std[SL] E[TWAP] Std[TWAP]  \
# noise_40                   Noise     40  -0.35    1.43   -0.58       1.1
# noise_120                           120  -2.75    1.29   -3.02      1.06
# flow_40        Noise \& Tactical     40   -2.0    1.43   -0.19       1.0
# flow_120                            120  -5.57    0.77   -4.13      1.03
# strategic_40   Noise \& Tactical     40  -2.11    3.29   -1.09      3.28
# strategic_120       \& Strategic    120  -3.96    4.01   -3.42      4.18
#
#               E[DR] Std[DR]           E[LN] Std[LN]
# noise_40        nan     nan    \textbf{0.3}     1.4
# noise_120       nan     nan  \textbf{-1.64}    1.21
# flow_40         nan     nan   \textbf{0.61}    0.75
# flow_120        nan     nan  \textbf{-0.72}    0.81
# strategic_40    nan     nan   \textbf{2.32}    3.69
# strategic_120   nan     nan   \textbf{0.26}    3.21

# %%
### density plot for deterministic actions 

lots_list = [40, 120]
textwidth = 6.75
textheight = 9
scale = 3.2

agent_names = ['sl_agent', 'linear_sl_agent', 'log_normal', 'dirichlet']
# without dirichlet
# this yields the correct ordering in the maps 
# agent_names = ['sl_agent', 'linear_sl_agent',  'log_normal', 'log_normal_learn_std']
# agent_names = ['sl_agent', 'linear_sl_agent', 'log_normal']
# agent_names = ['log_normal', 'sl_agent', 'linear_sl_agent']
for i, env in enumerate(['noise', 'flow', 'strategic']):
    print('#############')
    print('generating plots for ', env)
    fig, axs = plt.subplots(2, 1, figsize=(scale*0.3*textwidth, scale*0.3*textheight), dpi=300)
    for j, lots in enumerate(lots_list):
        ax = axs[j]
        for agent in agent_names:
            # names = {'sl_agent': 'SL', 'linear_sl_agent': 'TWAP', 'actor_critic': 'RL'} 
            name_translation = {'sl_agent': 'SL', 'linear_sl_agent': 'TWAP', 'log_normal': 'LN', 'dirichlet': 'DR', 'log_normal_learn_std': 'LNVR'}
            try: 
                if agent == 'log_normal':
                    z_order = 10
                else:
                    z_order = 1 
                sns.kdeplot(data[env][lots][agent], fill=False, label=name_translation[agent], bw_adjust=1, linewidth=3, ax=ax, zorder=z_order)
            except: 
                print(f"no data available for {env}, {lots}, {agent}")
        if env == 'noise' and lots == 40:   
            ax.legend(prop={'size': 16}, loc='upper left')
        # set legend at the top of ech market. can comment this out if necessary. 
        # if j == 0:
            # ax.legend(prop={'size': 16}, loc='upper left')  
        fig.set_dpi(150)
        if j == 1:
            ax.set_xlabel('Reward', fontsize=20)
            # ax.set_xlabel('X', fontsize=20)
        # ax.set_title(f'{env}', fontsize=18)
        if i == 0:
            ax.set_ylabel('Density', fontsize=20)
        else:
            ax.set_ylabel('')
        # set density label everywhere
        # comment out if necessary 
        ax.set_ylabel('Density', fontsize=20)
        # if i == 0:
            # ax.set_title(f'Noise', fontsize=18)
        # if j == 0:
        # ax.set_title(f'#Lots={n_lots}', fontsize=18)
        tick_size = 14
        ax.tick_params(axis='x', labelsize=tick_size)
        ax.tick_params(axis='y', labelsize=tick_size)
        ax.grid()
        ax.set_xticks(np.arange(-10, 10, 1))
        if env == 'noise':
            ax.set_xlim(-8, 3)
        elif env == 'flow':
            ax.set_xlim(-8, 3)
        elif env == 'strategic':
            ax.set_xticks(np.arange(-12, 12, 2))
            # ax.set_xlim(-10, 10)
            ax.set_xlim(-12, 10)
        else:
            pass
            # adjust xlim depending on experiments manually 
    plt.tight_layout() 
    tag = 'long_horizon'
    name = f'{parent_dir}/plots/reward_distribution_{env}_{tag}.pdf'
    print(f'saving to {name}')
    plt.savefig(name)
# Out:
# #############
# generating plots for  noise
# saving to /u/weim/lob/plots/reward_distribution_noise_long_horizon.pdf
# #############
# generating plots for  flow
# saving to /u/weim/lob/plots/reward_distribution_flow_long_horizon.pdf
# #############
# generating plots for  strategic
# saving to /u/weim/lob/plots/reward_distribution_strategic_long_horizon.pdf
